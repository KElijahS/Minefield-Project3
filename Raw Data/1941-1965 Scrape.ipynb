# %%
#Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import requests

# %%
#1941 Billboard
url41 = 'http://billboardtop100of.com/1941-2/'

# %%
tables41 = pd.read_html(url41)

# %%
tables41[0]
# Out:
#      0                    1                                      2
# 0    1         Glenn Miller                  Chattanooga Choo Choo
# 1    2           Sammy Kaye                                  Daddy
# 2    3           Artie Shaw                               Stardust
# 3    4  The Andrews Sisters                Boogie Woogie Bugle Boy
# 4    5         Jimmy Dorsey          Amapola (Pretty Little Poppy)
# ..  ..                  ...                                    ...
# 75  76            Kay Kyser              (Lights Out) Til Reveille
# 76  77          Tony Martin              The Last Time I Saw Paris
# 77  78         Tommy Tucker  I Don’t Want to Set the World On Fire
# 78  79         Guy Lombardo        Intermezzo (Souvenir De Vienne)
# 79  80     Anjos do Inferno                   Voce Ja Foi a Bahia?
#
# [80 rows x 3 columns]

# %%
df41 = tables41[0]

# %%
pd.DataFrame.to_csv(df41, 'top41.csv')

# %%
#1945 Billboard
url45 = 'http://billboardtop100of.com/1945-2/'
tables45 = pd.read_html(url45)
tables45[0]
# Out:
#      0                             1  \
# 0    1           The Andrews Sisters
# 1    2                     Les Brown
# 2    3                    Perry Como
# 3    4                     Les Brown
# 4    5                 Johnny Mercer
# ..  ..                           ...
# 75  76  Hal McIntyre & his Orchestra
# 76  77                   Johnny Long
# 77  78                  Betty Grable
# 78  79                Gilberto Alves
# 79  80               Dizzy Gillespie
#
#                                             2
# 0                             Rum & Coca-Cola
# 1                         Sentimental Journey
# 2                        Till The End of Time
# 3   My Dreams Are Getting Better All the Time
# 4      On the Atchison, Topeka & the Santa Fe
# ..                                        ...
# 75                        Sentimental Journey
# 76  My Dreams Are Getting Better All the Time
# 77                  I Can’t Begin to Tell You
# ...

# %%
df45 = tables45[0]

# %%
pd.DataFrame.to_csv(df45, 'top45.csv')

# %%
#1950 Billboard
url50 = 'http://billboardtop100of.com/1950-2/'
tables50 = pd.read_html(url50)
tables50[0]
# Out:
#      0                                   1  \
# 0    1      Gordon Jenkins and The Weavers
# 1    2                       Nat King Cole
# 2    3                         Anton Karas
# 3    4                Gary and Bing Crosby
# 4    5                Gary and Bing Crosby
# 5    6                       Teresa Brewer
# 6    7                        Guy Lombardo
# 7    8                           Red Foley
# 8    9                          Sammy Kaye
# 9   10          Sammy Kaye and Don Cornell
# 10  11                       Eileen Barton
# 11  12                           Kay Starr
# 12  13      Gordon Jenkins and The Weavers
# 13  14                         Tony Martin
# 14  15                         Phil Harris
# 15  16                       Ames Brothers
# 16  17  Andrews Sisters and Gordon Jenkins
# 17  18                          Patti Page
# 18  19  Andrews Sisters and Gordon Jenkins
# 19  20  Tennessee Ernie Ford and Kay Starr
# 20  21                          Patti Page
# ...

# %%
df50 = tables50[0]

# %%
pd.DataFrame.to_csv(df50, 'top50.csv')

# %%
#1955 Billboard
url55 = 'http://billboardtop100of.com/1955-2/'
tables55 = pd.read_html(url55)
tables55[0]
# Out:
#      0                                 1                                    2
# 0    1                       Perez Prado  Cherry Pink And Apple Blossom White
# 1    2         Bill Haley and His Comets                Rock Around The Clock
# 2    3                      Mitch Miller             The Yellow Rose Of Texas
# 3    4                    Roger Williams                        Autumn Leaves
# 4    5                        Les Baxter                     Unchained Melody
# 5    6                        Bill Hayes          The Ballad Of Davy Crockett
# 6    7                         Four Aces      Love Is A Many Splendored Thing
# 7    8                   McGuire Sisters                            Sincerely
# 8    9                         Pat Boone                   Ain’t That A Shame
# 9   10                     Georgia Gibbs                  Dance With Me Henry
# 10  11                        Crazy Otto             Crazy Otto Medley I & 11
# ...

# %%
df55 = tables55[0]
pd.DataFrame.to_csv(df55, 'top55.csv')

# %%
#1960 Billboard
url60 = 'http://billboardtop100of.com/1960-2/'
tables60 = pd.read_html(url60)
tables60[0]
# Out:
#       0                 1                            2
# 0     1       Percy Faith  Theme From “A Summer Place”
# 1     2        Jim Reeves             He’ll Have To Go
# 2     3   Everly Brothers                Cathy’s Clown
# 3     4    Johnny Preston                 Running Bear
# 4     5      Mark Dinning                   Teen Angel
# ..  ...               ...                          ...
# 95   96      Bobby Rydell            Little Bitty Girl
# 96   97     Barret Strong                        Money
# 97   98  Maurice Williams                         Stay
# 98   99      Charlie Rich              Lonely Weekends
# 99  100        Larry Hall                        Sandy
#
# [100 rows x 3 columns]

# %%
df60 = tables60[0]

# %%
pd.DataFrame.to_csv(df60, 'top60.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-13-942dd9e44cf9> in <module>
# ----> 1 pd.DataFrame.to_csv(df60, 'top60.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
# ...

# %%
#1965 Billboard
url65 = 'http://billboardtop100of.com/1965-2/'
tables65 = pd.read_html(url65)
tables65[0]
# Out:
#       0                              1  \
# 0     1  Sam The Sham and The Pharaohs
# 1     2                      Four Tops
# 2     3                 Rolling Stones
# 3     4                        We Five
# 4     5             Righteous Brothers
# ..  ...                            ...
# 95   96                     Jack Jones
# 96   97           Dino, Desi and Billy
# 97   98                        Ad Libs
# 98   99                    Del Shannon
# 99  100                    Marvin Gaye
#
#                                               2
# 0                                   Wooly Bully
# 1   I Can’t Help Myself (Sugar Pie Honey Bunch)
# 2                 (I Can’t Get No) Satisfaction
# 3                           You Were On My Mind
# 4               You’ve Lost That Lovin’ Feelin’
# ..                                          ...
# 95                               The Race Is On
# 96                                   I’m A Fool
# 97                   The Boy From New York City
# ...

# %%
df65 = tables65[0]
pd.DataFrame.to_csv(df65, 'top65.csv')
